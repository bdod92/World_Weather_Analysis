# %%
#import modules
import numpy as np
import pandas as pd

# %%
# Generate random array of lat and lng
lats = np.random.uniform(-90.00, 90.00, size = 2000)
lngs = np.random.uniform(-180.00, 180.00, size = 2000)

lat_lngs = zip(lats, lngs)

# %%
# store the lat / lng in a list
coordinates = list(lat_lngs)

# %%
#use the citipy module to determine the nearest city from the lat / lng
from citipy import citipy

# %%
# create list for holding the nearby cities
cities = []

#identify the city
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, then add to the list
    if city not in cities:
        cities.append(city)
# Out:
# 'rikitea'

# %%
# Import the time library and the datetime module
import time
from datetime import datetime
import requests as requests

# %%
# Import the API key
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = city_weather["dt"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date" : city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severnyy
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | gamba
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | itapirapua
# Processing Record 9 of Set 1 | qui nhon
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | rawson
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | dipkarpaz
# City not found. Skipping...
# Processing Record 16 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 1 | leningradskiy
# Processing Record 18 of Set 1 | dakar
# Processing Record 19 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 1 | kavaratti
# Processing Record 21 of Set 1 | whitehorse
# Processing Record 22 of Set 1 | dunedin
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | narsaq
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | kutum
# Processing Record 28 of Set 1 | esperance
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | muros
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | kuusamo
# Processing Record 36 of Set 1 | kontagora
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 1 | caravelas
# Processing Record 40 of Set 1 | puno
# Processing Record 41 of Set 1 | moerai
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | vila franca do campo
# Processing Record 46 of Set 1 | poltavka
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | siavonga
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | rocha
# Processing Record 6 of Set 2 | taltal
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | yulara
# Processing Record 11 of Set 2 | cravo norte
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | kijini
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | guerrero negro
# Processing Record 16 of Set 2 | khani
# Processing Record 17 of Set 2 | yinchuan
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | aviles
# Processing Record 20 of Set 2 | banswara
# Processing Record 21 of Set 2 | saint-augustin
# Processing Record 22 of Set 2 | ode
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | ketchikan
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | suzdal
# Processing Record 28 of Set 2 | fengzhen
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 2 | malyye derbety
# Processing Record 32 of Set 2 | guaruja
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 2 | emet
# Processing Record 36 of Set 2 | sorong
# Processing Record 37 of Set 2 | ranot
# Processing Record 38 of Set 2 | tosya
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | kropotkin
# Processing Record 41 of Set 2 | san lazaro
# Processing Record 42 of Set 2 | yamada
# Processing Record 43 of Set 2 | kenora
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | nivala
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | roebourne
# Processing Record 49 of Set 2 | chaohu
# Processing Record 50 of Set 2 | ascension
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | ixtapa
# Processing Record 5 of Set 3 | arlit
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | saint george
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | korla
# Processing Record 10 of Set 3 | tuatapere
# Processing Record 11 of Set 3 | cockburn town
# Processing Record 12 of Set 3 | bambous virieux
# Processing Record 13 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | whitianga
# Processing Record 15 of Set 3 | jaque
# Processing Record 16 of Set 3 | chama
# Processing Record 17 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 3 | saldanha
# Processing Record 19 of Set 3 | husavik
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | sergiyevsk
# Processing Record 22 of Set 3 | praia da vitoria
# Processing Record 23 of Set 3 | sovetskiy
# Processing Record 24 of Set 3 | bac giang
# Processing Record 25 of Set 3 | shingu
# Processing Record 26 of Set 3 | walvis bay
# Processing Record 27 of Set 3 | ust-nera
# Processing Record 28 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 3 | pangnirtung
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 32 of Set 3 | gat
# Processing Record 33 of Set 3 | rio de janeiro
# Processing Record 34 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | cabedelo
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | flin flon
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | sibolga
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | ginir
# Processing Record 44 of Set 3 | la union
# Processing Record 45 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 3 | grindavik
# Processing Record 47 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 3 | ambilobe
# Processing Record 49 of Set 3 | coahuayana
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | bithur
# Processing Record 2 of Set 4 | moose factory
# Processing Record 3 of Set 4 | erdenet
# Processing Record 4 of Set 4 | salta
# Processing Record 5 of Set 4 | mount gambier
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | fort nelson
# Processing Record 8 of Set 4 | santo tomas
# Processing Record 9 of Set 4 | dombarovskiy
# Processing Record 10 of Set 4 | roald
# Processing Record 11 of Set 4 | nanortalik
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | marzuq
# Processing Record 14 of Set 4 | manaure
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | bluff
# Processing Record 17 of Set 4 | cidreira
# Processing Record 18 of Set 4 | sola
# Processing Record 19 of Set 4 | santa cruz
# Processing Record 20 of Set 4 | punta cardon
# Processing Record 21 of Set 4 | sinnamary
# Processing Record 22 of Set 4 | srednekolymsk
# Processing Record 23 of Set 4 | nagornskiy
# Processing Record 24 of Set 4 | lagoa
# Processing Record 25 of Set 4 | kant
# Processing Record 26 of Set 4 | tarko-sale
# Processing Record 27 of Set 4 | pisco
# Processing Record 28 of Set 4 | fort payne
# Processing Record 29 of Set 4 | rio gallegos
# Processing Record 30 of Set 4 | salinas
# Processing Record 31 of Set 4 | chuy
# Processing Record 32 of Set 4 | avera
# Processing Record 33 of Set 4 | xiamen
# Processing Record 34 of Set 4 | pitkyaranta
# Processing Record 35 of Set 4 | lindi
# Processing Record 36 of Set 4 | kahului
# Processing Record 37 of Set 4 | sturgeon falls
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | lazaro cardenas
# Processing Record 40 of Set 4 | nikolskoye
# Processing Record 41 of Set 4 | malm
# Processing Record 42 of Set 4 | ustye
# Processing Record 43 of Set 4 | flinders
# Processing Record 44 of Set 4 | omboue
# Processing Record 45 of Set 4 | gravdal
# Processing Record 46 of Set 4 | rognan
# Processing Record 47 of Set 4 | klyuchi
# Processing Record 48 of Set 4 | ust-kalmanka
# Processing Record 49 of Set 4 | lima
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | barraute
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | iskateley
# Processing Record 4 of Set 5 | tiznit
# Processing Record 5 of Set 5 | porto walter
# Processing Record 6 of Set 5 | saint-francois
# Processing Record 7 of Set 5 | guarapari
# Processing Record 8 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 5 | oskarshamn
# Processing Record 10 of Set 5 | san patricio
# Processing Record 11 of Set 5 | baijiantan
# Processing Record 12 of Set 5 | naze
# Processing Record 13 of Set 5 | shuyskoye
# Processing Record 14 of Set 5 | faanui
# Processing Record 15 of Set 5 | sao filipe
# Processing Record 16 of Set 5 | vaitape
# Processing Record 17 of Set 5 | luderitz
# Processing Record 18 of Set 5 | sebezh
# Processing Record 19 of Set 5 | sorland
# Processing Record 20 of Set 5 | qaanaaq
# Processing Record 21 of Set 5 | faya
# Processing Record 22 of Set 5 | timaru
# Processing Record 23 of Set 5 | alofi
# Processing Record 24 of Set 5 | puerto colombia
# Processing Record 25 of Set 5 | tezu
# Processing Record 26 of Set 5 | aguimes
# Processing Record 27 of Set 5 | elko
# Processing Record 28 of Set 5 | olga
# Processing Record 29 of Set 5 | port hedland
# Processing Record 30 of Set 5 | buraydah
# Processing Record 31 of Set 5 | morehead
# Processing Record 32 of Set 5 | aripuana
# Processing Record 33 of Set 5 | deputatskiy
# Processing Record 34 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 5 | nanakuli
# Processing Record 36 of Set 5 | muscat
# Processing Record 37 of Set 5 | oktyabrskoye
# Processing Record 38 of Set 5 | bytosh
# Processing Record 39 of Set 5 | mar del plata
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | isla vista
# Processing Record 42 of Set 5 | tromso
# Processing Record 43 of Set 5 | road town
# Processing Record 44 of Set 5 | fairbanks
# Processing Record 45 of Set 5 | sao joao da barra
# Processing Record 46 of Set 5 | meulaboh
# Processing Record 47 of Set 5 | cross lanes
# Processing Record 48 of Set 5 | bose
# Processing Record 49 of Set 5 | hit
# Processing Record 50 of Set 5 | beaufort
# Processing Record 1 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 2 of Set 6 | tyup
# Processing Record 3 of Set 6 | coquimbo
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | ahuimanu
# Processing Record 6 of Set 6 | aromashevo
# Processing Record 7 of Set 6 | lahad datu
# Processing Record 8 of Set 6 | khandyga
# Processing Record 9 of Set 6 | kabinda
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | san jeronimo
# Processing Record 12 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 6 | maceio
# Processing Record 14 of Set 6 | solms
# Processing Record 15 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 16 of Set 6 | guantanamo
# Processing Record 17 of Set 6 | waitati
# Processing Record 18 of Set 6 | punta de bombon
# Processing Record 19 of Set 6 | garden city
# Processing Record 20 of Set 6 | vuktyl
# Processing Record 21 of Set 6 | hithadhoo
# Processing Record 22 of Set 6 | panama city
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | pueblo nuevo
# Processing Record 25 of Set 6 | durango
# Processing Record 26 of Set 6 | souillac
# Processing Record 27 of Set 6 | nemuro
# Processing Record 28 of Set 6 | necochea
# Processing Record 29 of Set 6 | cherskiy
# Processing Record 30 of Set 6 | huilong
# Processing Record 31 of Set 6 | skage
# City not found. Skipping...
# Processing Record 32 of Set 6 | paradise
# Processing Record 33 of Set 6 | nome
# Processing Record 34 of Set 6 | tifton
# Processing Record 35 of Set 6 | skjervoy
# Processing Record 36 of Set 6 | sovetskaya gavan
# Processing Record 37 of Set 6 | neryungri
# Processing Record 38 of Set 6 | atar
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | sinjar
# Processing Record 41 of Set 6 | takoradi
# Processing Record 42 of Set 6 | grieskirchen
# Processing Record 43 of Set 6 | lasa
# Processing Record 44 of Set 6 | mancio lima
# Processing Record 45 of Set 6 | nobeoka
# Processing Record 46 of Set 6 | filingue
# Processing Record 47 of Set 6 | forestville
# Processing Record 48 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 6 | nador
# Processing Record 50 of Set 6 | phan thiet
# Processing Record 1 of Set 7 | rosita
# Processing Record 2 of Set 7 | yaan
# Processing Record 3 of Set 7 | jerez
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | shar
# Processing Record 6 of Set 7 | san quintin
# Processing Record 7 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 7 | kurchum
# Processing Record 9 of Set 7 | nueva loja
# Processing Record 10 of Set 7 | coolum beach
# Processing Record 11 of Set 7 | menongue
# Processing Record 12 of Set 7 | ormara
# Processing Record 13 of Set 7 | shahgarh
# Processing Record 14 of Set 7 | ouargaye
# Processing Record 15 of Set 7 | saint-joseph
# Processing Record 16 of Set 7 | little current
# Processing Record 17 of Set 7 | victoria point
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | port hardy
# Processing Record 20 of Set 7 | talnakh
# Processing Record 21 of Set 7 | yaviza
# Processing Record 22 of Set 7 | beroroha
# Processing Record 23 of Set 7 | pathein
# Processing Record 24 of Set 7 | katsuura
# Processing Record 25 of Set 7 | willmar
# Processing Record 26 of Set 7 | poum
# Processing Record 27 of Set 7 | turuvekere
# Processing Record 28 of Set 7 | seymchan
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | lompoc
# Processing Record 31 of Set 7 | presidencia roque saenz pena
# Processing Record 32 of Set 7 | barcelos
# Processing Record 33 of Set 7 | windhoek
# Processing Record 34 of Set 7 | jiuquan
# Processing Record 35 of Set 7 | boa vista
# Processing Record 36 of Set 7 | asfi
# Processing Record 37 of Set 7 | kango
# Processing Record 38 of Set 7 | kholmogory
# Processing Record 39 of Set 7 | jardim
# Processing Record 40 of Set 7 | elizabeth city
# Processing Record 41 of Set 7 | birmitrapur
# Processing Record 42 of Set 7 | simoes
# Processing Record 43 of Set 7 | klaksvik
# Processing Record 44 of Set 7 | coos bay
# Processing Record 45 of Set 7 | auki
# Processing Record 46 of Set 7 | hambantota
# Processing Record 47 of Set 7 | vilyuysk
# Processing Record 48 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 7 | lakhnadon
# Processing Record 50 of Set 7 | daru
# Processing Record 1 of Set 8 | nabire
# Processing Record 2 of Set 8 | marsa matruh
# Processing Record 3 of Set 8 | la rioja
# Processing Record 4 of Set 8 | tura
# Processing Record 5 of Set 8 | el alto
# Processing Record 6 of Set 8 | mareeba
# Processing Record 7 of Set 8 | provideniya
# Processing Record 8 of Set 8 | marienburg
# Processing Record 9 of Set 8 | te anau
# Processing Record 10 of Set 8 | beyneu
# Processing Record 11 of Set 8 | ola
# Processing Record 12 of Set 8 | muli
# Processing Record 13 of Set 8 | belyy yar
# Processing Record 14 of Set 8 | areia branca
# Processing Record 15 of Set 8 | makinsk
# Processing Record 16 of Set 8 | vestmannaeyjar
# Processing Record 17 of Set 8 | key west
# Processing Record 18 of Set 8 | itarema
# Processing Record 19 of Set 8 | mukdahan
# Processing Record 20 of Set 8 | havelock
# Processing Record 21 of Set 8 | ellensburg
# Processing Record 22 of Set 8 | tacna
# Processing Record 23 of Set 8 | matara
# Processing Record 24 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 8 | aklavik
# Processing Record 26 of Set 8 | pundaguitan
# Processing Record 27 of Set 8 | villa carlos paz
# Processing Record 28 of Set 8 | goderich
# Processing Record 29 of Set 8 | nioro
# Processing Record 30 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 8 | mendi
# Processing Record 32 of Set 8 | leninskoye
# Processing Record 33 of Set 8 | waingapu
# Processing Record 34 of Set 8 | la ronge
# Processing Record 35 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 8 | bowen
# Processing Record 37 of Set 8 | lambarene
# Processing Record 38 of Set 8 | bacolod
# Processing Record 39 of Set 8 | labuhan
# Processing Record 40 of Set 8 | anchorage
# Processing Record 41 of Set 8 | camacha
# Processing Record 42 of Set 8 | mahebourg
# Processing Record 43 of Set 8 | hirara
# Processing Record 44 of Set 8 | petrinja
# Processing Record 45 of Set 8 | seoul
# Processing Record 46 of Set 8 | nantucket
# Processing Record 47 of Set 8 | voyvozh
# Processing Record 48 of Set 8 | douentza
# Processing Record 49 of Set 8 | soe
# Processing Record 50 of Set 8 | shima
# Processing Record 1 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 9 | aqtobe
# Processing Record 3 of Set 9 | sao miguel do araguaia
# Processing Record 4 of Set 9 | leopold
# Processing Record 5 of Set 9 | comodoro rivadavia
# Processing Record 6 of Set 9 | balykshi
# Processing Record 7 of Set 9 | hasaki
# Processing Record 8 of Set 9 | severo-kurilsk
# Processing Record 9 of Set 9 | limburg
# Processing Record 10 of Set 9 | ichinohe
# Processing Record 11 of Set 9 | santa maria
# Processing Record 12 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 9 | bam
# Processing Record 14 of Set 9 | yar-sale
# Processing Record 15 of Set 9 | tazovskiy
# Processing Record 16 of Set 9 | dickinson
# Processing Record 17 of Set 9 | santa clarita
# Processing Record 18 of Set 9 | aizkraukle
# Processing Record 19 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 20 of Set 9 | yuanping
# Processing Record 21 of Set 9 | college
# Processing Record 22 of Set 9 | mackay
# Processing Record 23 of Set 9 | constitucion
# Processing Record 24 of Set 9 | socorro
# Processing Record 25 of Set 9 | dodge city
# Processing Record 26 of Set 9 | richards bay
# Processing Record 27 of Set 9 | outjo
# Processing Record 28 of Set 9 | port hawkesbury
# Processing Record 29 of Set 9 | the valley
# Processing Record 30 of Set 9 | acari
# Processing Record 31 of Set 9 | almaznyy
# Processing Record 32 of Set 9 | clarence town
# Processing Record 33 of Set 9 | valledupar
# Processing Record 34 of Set 9 | mitsamiouli
# Processing Record 35 of Set 9 | teya
# Processing Record 36 of Set 9 | krasnogorsk
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | ihosy
# Processing Record 39 of Set 9 | honningsvag
# Processing Record 40 of Set 9 | chandvad
# Processing Record 41 of Set 9 | kemin
# Processing Record 42 of Set 9 | tsentralnyy
# City not found. Skipping...
# Processing Record 43 of Set 9 | lavrentiya
# Processing Record 44 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 9 | jimo
# Processing Record 46 of Set 9 | chokurdakh
# Processing Record 47 of Set 9 | lagos de moreno
# Processing Record 48 of Set 9 | qaqortoq
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | grand-lahou
# Processing Record 1 of Set 10 | quesnel
# Processing Record 2 of Set 10 | mandalgovi
# Processing Record 3 of Set 10 | bongandanga
# Processing Record 4 of Set 10 | gladstone
# Processing Record 5 of Set 10 | iaciara
# Processing Record 6 of Set 10 | lastoursville
# Processing Record 7 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 10 | kirakira
# Processing Record 9 of Set 10 | eyl
# Processing Record 10 of Set 10 | samarai
# Processing Record 11 of Set 10 | dawei
# Processing Record 12 of Set 10 | tianpeng
# Processing Record 13 of Set 10 | pecanha
# Processing Record 14 of Set 10 | egvekinot
# Processing Record 15 of Set 10 | roros
# Processing Record 16 of Set 10 | payakumbuh
# Processing Record 17 of Set 10 | morant bay
# Processing Record 18 of Set 10 | kankan
# Processing Record 19 of Set 10 | carlsbad
# Processing Record 20 of Set 10 | aykhal
# Processing Record 21 of Set 10 | drumheller
# Processing Record 22 of Set 10 | hovd
# Processing Record 23 of Set 10 | westport
# Processing Record 24 of Set 10 | paamiut
# Processing Record 25 of Set 10 | tucurui
# Processing Record 26 of Set 10 | bengkulu
# Processing Record 27 of Set 10 | cam ranh
# Processing Record 28 of Set 10 | aktas
# Processing Record 29 of Set 10 | liku
# Processing Record 30 of Set 10 | haines junction
# Processing Record 31 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 10 | portland
# Processing Record 33 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 10 | mersing
# Processing Record 35 of Set 10 | ha giang
# Processing Record 36 of Set 10 | geraldton
# Processing Record 37 of Set 10 | puerto escondido
# Processing Record 38 of Set 10 | vicar
# Processing Record 39 of Set 10 | ayagoz
# Processing Record 40 of Set 10 | luanda
# Processing Record 41 of Set 10 | santa rosa
# Processing Record 42 of Set 10 | port blair
# Processing Record 43 of Set 10 | san joaquin
# Processing Record 44 of Set 10 | qurayyat
# Processing Record 45 of Set 10 | saint-georges
# Processing Record 46 of Set 10 | poyarkovo
# Processing Record 47 of Set 10 | kashi
# Processing Record 48 of Set 10 | xuddur
# Processing Record 49 of Set 10 | cayenne
# Processing Record 50 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 11 | bracebridge
# Processing Record 2 of Set 11 | winnemucca
# Processing Record 3 of Set 11 | fuling
# Processing Record 4 of Set 11 | monster
# Processing Record 5 of Set 11 | mtwara
# Processing Record 6 of Set 11 | whitehaven
# Processing Record 7 of Set 11 | sabha
# Processing Record 8 of Set 11 | christchurch
# Processing Record 9 of Set 11 | doha
# Processing Record 10 of Set 11 | kumbo
# Processing Record 11 of Set 11 | dingle
# Processing Record 12 of Set 11 | zyryanovsk
# Processing Record 13 of Set 11 | bull savanna
# Processing Record 14 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 11 | kloulklubed
# Processing Record 16 of Set 11 | sechura
# Processing Record 17 of Set 11 | trenggalek
# Processing Record 18 of Set 11 | pilar
# Processing Record 19 of Set 11 | chabahar
# Processing Record 20 of Set 11 | sambava
# Processing Record 21 of Set 11 | vawkavysk
# Processing Record 22 of Set 11 | padang
# Processing Record 23 of Set 11 | santa fe
# Processing Record 24 of Set 11 | dali
# Processing Record 25 of Set 11 | knysna
# Processing Record 26 of Set 11 | champerico
# Processing Record 27 of Set 11 | gardan diwal
# City not found. Skipping...
# Processing Record 28 of Set 11 | harnosand
# Processing Record 29 of Set 11 | sumbe
# Processing Record 30 of Set 11 | dwarka
# Processing Record 31 of Set 11 | hofn
# Processing Record 32 of Set 11 | el dorado
# Processing Record 33 of Set 11 | berlevag
# Processing Record 34 of Set 11 | awjilah
# Processing Record 35 of Set 11 | chegdomyn
# Processing Record 36 of Set 11 | juba
# Processing Record 37 of Set 11 | sale
# Processing Record 38 of Set 11 | sao jose da coroa grande
# Processing Record 39 of Set 11 | sohag
# Processing Record 40 of Set 11 | saskylakh
# Processing Record 41 of Set 11 | oranjestad
# Processing Record 42 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 11 | kapit
# Processing Record 44 of Set 11 | quirinopolis
# Processing Record 45 of Set 11 | troitsko-pechorsk
# Processing Record 46 of Set 11 | ventspils
# Processing Record 47 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 48 of Set 11 | chicama
# Processing Record 49 of Set 11 | tongchuan
# Processing Record 50 of Set 11 | russell
# Processing Record 1 of Set 12 | uyuni
# Processing Record 2 of Set 12 | svetlyy
# Processing Record 3 of Set 12 | banda aceh
# Processing Record 4 of Set 12 | arona
# Processing Record 5 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 12 | senanga
# Processing Record 7 of Set 12 | alekseyevka
# Processing Record 8 of Set 12 | dijkot
# Processing Record 9 of Set 12 | katangli
# Processing Record 10 of Set 12 | shevchenkove
# Processing Record 11 of Set 12 | krasnyy kut
# Processing Record 12 of Set 12 | karpinsk
# Processing Record 13 of Set 12 | toba
# Processing Record 14 of Set 12 | cairo
# Processing Record 15 of Set 12 | oranjemund
# Processing Record 16 of Set 12 | yantal
# Processing Record 17 of Set 12 | batagay-alyta
# Processing Record 18 of Set 12 | hokitika
# Processing Record 19 of Set 12 | kakogawa
# Processing Record 20 of Set 12 | borger
# Processing Record 21 of Set 12 | santa isabel
# Processing Record 22 of Set 12 | tautira
# Processing Record 23 of Set 12 | palmer
# Processing Record 24 of Set 12 | banepa
# Processing Record 25 of Set 12 | vanimo
# Processing Record 26 of Set 12 | kamaishi
# Processing Record 27 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 12 | opuwo
# Processing Record 29 of Set 12 | krasnomayskiy
# Processing Record 30 of Set 12 | golden
# Processing Record 31 of Set 12 | tombouctou
# Processing Record 32 of Set 12 | vao
# Processing Record 33 of Set 12 | burnie
# Processing Record 34 of Set 12 | kaduy
# Processing Record 35 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 12 | sao bartolomeu de messines
# Processing Record 37 of Set 12 | shenjiamen
# Processing Record 38 of Set 12 | turbat
# Processing Record 39 of Set 12 | norsup
# Processing Record 40 of Set 12 | merrill
# Processing Record 41 of Set 12 | kieta
# Processing Record 42 of Set 12 | lyngseidet
# Processing Record 43 of Set 12 | kamina
# Processing Record 44 of Set 12 | makakilo city
# Processing Record 45 of Set 12 | jacareacanga
# Processing Record 46 of Set 12 | shakawe
# Processing Record 47 of Set 12 | sabzevar
# Processing Record 48 of Set 12 | salalah
# Processing Record 49 of Set 12 | manduria
# Processing Record 50 of Set 12 | margate
# Processing Record 1 of Set 13 | anadyr
# Processing Record 2 of Set 13 | taguatinga
# Processing Record 3 of Set 13 | varkkallai
# Processing Record 4 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 5 of Set 13 | juneau
# Processing Record 6 of Set 13 | waipawa
# Processing Record 7 of Set 13 | ilulissat
# Processing Record 8 of Set 13 | beringovskiy
# Processing Record 9 of Set 13 | ciudad guayana
# Processing Record 10 of Set 13 | karpathos
# Processing Record 11 of Set 13 | iquique
# Processing Record 12 of Set 13 | miastko
# Processing Record 13 of Set 13 | rudbar
# Processing Record 14 of Set 13 | najran
# Processing Record 15 of Set 13 | tambopata
# Processing Record 16 of Set 13 | dongying
# Processing Record 17 of Set 13 | itamaraju
# Processing Record 18 of Set 13 | guilin
# Processing Record 19 of Set 13 | collie
# Processing Record 20 of Set 13 | sulecin
# Processing Record 21 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 22 of Set 13 | campoverde
# Processing Record 23 of Set 13 | namatanai
# Processing Record 24 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 13 | ossora
# Processing Record 26 of Set 13 | mahajanga
# Processing Record 27 of Set 13 | los llanos de aridane
# Processing Record 28 of Set 13 | tessalit
# Processing Record 29 of Set 13 | eureka
# Processing Record 30 of Set 13 | rio grande
# Processing Record 31 of Set 13 | porbandar
# Processing Record 32 of Set 13 | coachella
# Processing Record 33 of Set 13 | namie
# Processing Record 34 of Set 13 | talesh
# City not found. Skipping...
# Processing Record 35 of Set 13 | cap malheureux
# Processing Record 36 of Set 13 | imbituba
# Processing Record 37 of Set 13 | cabra
# Processing Record 38 of Set 13 | darab
# Processing Record 39 of Set 13 | lubango
# Processing Record 40 of Set 13 | fortuna
# Processing Record 41 of Set 13 | buckeye
# Processing Record 42 of Set 13 | ipiales
# Processing Record 43 of Set 13 | hamilton
# Processing Record 44 of Set 13 | angra
# City not found. Skipping...
# Processing Record 45 of Set 13 | de aar
# Processing Record 46 of Set 13 | sioux lookout
# Processing Record 47 of Set 13 | coihaique
# Processing Record 48 of Set 13 | rovaniemi
# Processing Record 49 of Set 13 | sainte-maxime
# Processing Record 50 of Set 13 | murray bridge
# Processing Record 1 of Set 14 | rota
# Processing Record 2 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 14 | pak phanang
# Processing Record 4 of Set 14 | powell river
# Processing Record 5 of Set 14 | sheridan
# Processing Record 6 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 14 | senno
# Processing Record 8 of Set 14 | vostok
# Processing Record 9 of Set 14 | sukumo
# Processing Record 10 of Set 14 | maarianhamina
# Processing Record 11 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 14 | manggar
# Processing Record 13 of Set 14 | mount isa
# Processing Record 14 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 14 | henties bay
# Processing Record 16 of Set 14 | khasan
# Processing Record 17 of Set 14 | sadowara
# City not found. Skipping...
# Processing Record 18 of Set 14 | sakaiminato
# Processing Record 19 of Set 14 | pacific grove
# Processing Record 20 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 14 | vagamo
# Processing Record 22 of Set 14 | sioux falls
# Processing Record 23 of Set 14 | zhob
# Processing Record 24 of Set 14 | sterling
# Processing Record 25 of Set 14 | alice springs
# Processing Record 26 of Set 14 | taoudenni
# Processing Record 27 of Set 14 | nagato
# Processing Record 28 of Set 14 | sarakhs
# Processing Record 29 of Set 14 | kharp
# Processing Record 30 of Set 14 | quatre cocos
# Processing Record 31 of Set 14 | sanming
# Processing Record 32 of Set 14 | codigoro
# Processing Record 33 of Set 14 | lashio
# Processing Record 34 of Set 14 | malinovskiy
# Processing Record 35 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 14 | sao paulo de olivenca
# Processing Record 37 of Set 14 | svetlogorsk
# Processing Record 38 of Set 14 | ahipara
# Processing Record 39 of Set 14 | varzea da palma
# Processing Record 40 of Set 14 | pingliang
# Processing Record 41 of Set 14 | puerto del rosario
# Processing Record 42 of Set 14 | burica
# City not found. Skipping...
# Processing Record 43 of Set 14 | kudahuvadhoo
# Processing Record 44 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 14 | saint anthony
# Processing Record 46 of Set 14 | pokhara
# Processing Record 47 of Set 14 | funadhoo
# Processing Record 48 of Set 14 | mosquera
# Processing Record 49 of Set 14 | malindi
# Processing Record 50 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 15 | darhan
# Processing Record 2 of Set 15 | abha
# Processing Record 3 of Set 15 | kimamba
# Processing Record 4 of Set 15 | iqaluit
# Processing Record 5 of Set 15 | huejuquilla el alto
# Processing Record 6 of Set 15 | kamenka
# Processing Record 7 of Set 15 | rosehearty
# Processing Record 8 of Set 15 | agua dulce
# Processing Record 9 of Set 15 | bonga
# Processing Record 10 of Set 15 | port-gentil
# Processing Record 11 of Set 15 | kuldur
# Processing Record 12 of Set 15 | scarborough
# Processing Record 13 of Set 15 | floro
# Processing Record 14 of Set 15 | playa vicente
# Processing Record 15 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 15 | manhumirim
# Processing Record 17 of Set 15 | male
# Processing Record 18 of Set 15 | harper
# Processing Record 19 of Set 15 | keti bandar
# Processing Record 20 of Set 15 | kuldiga
# Processing Record 21 of Set 15 | terney
# Processing Record 22 of Set 15 | elliot lake
# Processing Record 23 of Set 15 | soskovo
# Processing Record 24 of Set 15 | isla mujeres
# Processing Record 25 of Set 15 | rongcheng
# Processing Record 26 of Set 15 | kajiado
# Processing Record 27 of Set 15 | sokoto
# Processing Record 28 of Set 15 | cah ab
# City not found. Skipping...
# Processing Record 29 of Set 15 | safford
# Processing Record 30 of Set 15 | inhambane
# Processing Record 31 of Set 15 | viedma
# Processing Record 32 of Set 15 | gigmoto
# Processing Record 33 of Set 15 | sept-iles
# Processing Record 34 of Set 15 | heihe
# Processing Record 35 of Set 15 | ambon
# Processing Record 36 of Set 15 | shelburne
# Processing Record 37 of Set 15 | zhigansk
# Processing Record 38 of Set 15 | jiwani
# Processing Record 39 of Set 15 | moroni
# Processing Record 40 of Set 15 | mikhaylovka
# Processing Record 41 of Set 15 | kiama
# Processing Record 42 of Set 15 | okakarara
# Processing Record 43 of Set 15 | bonavista
# Processing Record 44 of Set 15 | san juan del sur
# Processing Record 45 of Set 15 | almeirim
# Processing Record 46 of Set 15 | cocobeach
# Processing Record 47 of Set 15 | kushima
# Processing Record 48 of Set 15 | kjollefjord
# Processing Record 49 of Set 15 | bilibino
# Processing Record 50 of Set 15 | carballo
# Processing Record 1 of Set 16 | kostomuksha
# Processing Record 2 of Set 16 | waqqas
# Processing Record 3 of Set 16 | bend
# Processing Record 4 of Set 16 | keflavik
# Processing Record 5 of Set 16 | bobo dioulasso
# Processing Record 6 of Set 16 | adrar
# Processing Record 7 of Set 16 | liepaja
# Processing Record 8 of Set 16 | gura teghii
# Processing Record 9 of Set 16 | tijara
# Processing Record 10 of Set 16 | jega
# Processing Record 11 of Set 16 | kiunga
# Processing Record 12 of Set 16 | kisangani
# Processing Record 13 of Set 16 | sao gabriel da cachoeira
# Processing Record 14 of Set 16 | bima
# Processing Record 15 of Set 16 | mucurapo
# Processing Record 16 of Set 16 | pochutla
# Processing Record 17 of Set 16 | hornepayne
# Processing Record 18 of Set 16 | melfi
# Processing Record 19 of Set 16 | kavarna
# Processing Record 20 of Set 16 | luena
# Processing Record 21 of Set 16 | nanyamba
# Processing Record 22 of Set 16 | salinopolis
# Processing Record 23 of Set 16 | bolungarvik
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Severnyy      RU  50.6770   36.5532     51.84        58           0
# 1       Rikitea      PF -23.1203 -134.9692     75.47        61           8
# 2        Barrow      US  71.2906 -156.7887     -7.58        77           0
# 3     Busselton      AU -33.6500  115.3333     81.27        50          85
# 4         Gamba      GA  -2.6500   10.0000     74.26        92         100
# 5      Hermanus      ZA -34.4187   19.2345     59.81        73          94
# 6  Punta Arenas      CL -53.1500  -70.9167     38.59        84          29
# 7    Itapirapua      BR -15.8233  -50.6133     70.63        89          36
# 8      Qui Nhon      VN  13.7667  109.2333     80.44        72          88
# 9    Butaritari      KI   3.0707  172.7902     82.02        73          40
#
#    Wind Speed Current Description        Date
# 0        8.95           clear sky  1648875749
# 1       13.31           clear sky  1648875749
# 2       17.27           clear sky  1648875750
# 3        9.91     overcast clouds  1648875750
# 4        5.41     overcast clouds  1648875751
# 5       14.29     overcast clouds  1648875751
# 6        4.61    scattered clouds  1648875751
# 7        4.54    scattered clouds  1648875752
# 8       22.79     overcast clouds  1648875752
# 9       18.79    scattered clouds  1648875753

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Severnyy      RU  50.6770   36.5532     51.84        58           0
# 1        Rikitea      PF -23.1203 -134.9692     75.47        61           8
# 2         Barrow      US  71.2906 -156.7887     -7.58        77           0
# 3      Busselton      AU -33.6500  115.3333     81.27        50          85
# 4          Gamba      GA  -2.6500   10.0000     74.26        92         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 701        Melfi      IT  40.9965   15.6514     42.49        80          52
# 702      Kavarna      BG  43.4333   28.3333     56.48        87          60
# 703        Luena      AO -11.7833   19.9167     61.09        98          93
# 704     Nanyamba      TZ -10.6833   39.8333     73.42        93          97
# 705  Salinopolis      BR  -0.6136  -47.3561     76.44        90          98
#
#      Wind Speed Current Description
# 0          8.95           clear sky
# 1         13.31           clear sky
# 2         17.27           clear sky
# 3          9.91     overcast clouds
# 4          5.41     overcast clouds
# ..          ...                 ...
# 701        9.31       broken clouds
# 702       16.15       broken clouds
# 703        1.12          light rain
# 704        2.62     overcast clouds
# 705        7.31          light rain
#
# [706 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
